# %%
import requests
from bs4 import BeautifulSoup

# %%
# URL to be scraped
url = "https://www.marca.com/futbol/primera-division/clasificacion.html"

# Send GET request to the URL
response = requests.get(url)

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# # Extract the standings or relevant section
# # Example: Find a specific class or element that contains the standings
# standings_section = soup.find('div', {'id': 'wptab-2'})  # This is an example

# if standings_section:
#     standings_data = standings_section.text
#     print(standings_data)
# else:
#     print("Standings section not found.")

# %%
laliga_url = 'https://api.unidadeditorial.es/sports/v1/classifications/current/?site=2&type=10&tournament=0101'

laliga_data = requests.get(laliga_url)

laliga_soup = BeautifulSoup(laliga_data.text, 'html.parser')

# %%
print(laliga_soup)
# Out:
# {"status":"success","data":[{"id":"10_01_0101_2024_13_0_19","lastUpdate":"2024-12-23T10:14:56.435Z","classificationHead":{"classificationType":{"id":10,"name":"General","alternateNames":{"esES":"General","enEN":"General"}},"group":{"id":"0","name":"Único","alternateNames":{"esES":"Único","enEN":"Only"},"romanNumerals":""},"matchDay":19,"phase":{"id":13,"name":"Fase regular","alternateNames":{"esES":"Fase regular","enEN":"Regular season"}},"subphase":{},"season":{"id":2024,"name":"2024-25"},"sport":{"id":"01","name":"Fútbol","alternateNames":{"esES":"Fútbol","enEN":"Soccer"},"type":"match"},"tournament":{"id":"0101","name":"LaLiga EA Sports","alternateNames":{"esES":"LaLiga EA Sports","enEN":"LaLiga","itIT":"","ptBR":""},"isNational":false}},"rank":[{"id":"175","name":"Atlético","fullName":"Atlético de Madrid","alternateCommonNames":{"esES":"Atlético","enEN":"Atletico","itIT":"Atlético","ptBR":"Atlético"},"country":"ESP","countryName":"España","alternateCountryNames":{"esES":"España",
# ...

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
# <html lang="es"><head><link href="https://e00-marca.uecdn.es/assets/static/marca/v2/main.a7a7dd1d937839623c1b.css" rel="stylesheet" type="text/css"/>
# ...
